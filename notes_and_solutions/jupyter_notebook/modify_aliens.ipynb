# %%
# Step 1: create an empty list to store cars

# Step 2: make 5 cars using a loop, each car has color "white" and type "sedan"

# Step 3: loop through only the first 2 cars using a slice
    # Step 3a: check if the car's color is "white"
        # Step 3b: change the color to "black"
        # Step 3c: change the type to "suv"

# Step 4: print all 5 cars using a loop

# my first try with mistake
cars = []

for car_number in range(5):
    car_data = {"color": "white", "type": "sedan"}
    cars.append(car_data)

for car in cars[:2]:
    if car_data["color"] == "white":
        car_data["color"] = "black"
        car_data["type"] = "suv"
        
for car in cars:
    print(car)

# second try
cars = []

for car_value in range(5):
    car_data = {"color": "white", "type": "sedan"}
    cars.append(car_data)
    
for car in cars[:2]:
    if car["color"] == "white":
        car["color"] = "black"
        car["type"] = "suv"
        
for car in cars:
    print(car)

# %% [markdown]
# # Understanding the Python Code for Car Management
# ## Introduction
# In this document, we will explore a Python code snippet that manages a list of cars. The code creates a list of five cars, modifies the first two cars, and then prints the details of all cars. We will also analyze the mistakes made in the initial attempt and provide a clear explanation of the corrections made in the revised version.
#
# ## Key Concepts
# 1. **Lists in Python:** A list is a mutable sequence that can hold a collection of items. In this case, we are using a list to store dictionaries representing cars.
# 2. **Dictionaries:** A dictionary in Python is a collection of key-value pairs. Each car is represented as a dictionary with attributes like color and type.
# 3. **Loops:** We utilize loops to iterate over a range of numbers and to traverse through the list of cars.
# 4. **Slicing:** Slicing allows us to access a subset of the list. Here, we are interested in the first two cars.
#
# ## Code Structure
# The code is structured in four main steps:
# 1. **Initialization:** Create an empty list to store car data.
# 2. **Car Creation:** Use a loop to create five cars, each initialized with a color of "white" and a type of "sedan".
# 3. **Modification:** Loop through the first two cars and change their attributes if they meet certain conditions.
# 4. **Output:** Print the details of all cars in the list.
#
# ## Code Examples
# _Initial Attempt with Mistake_

# %%
cars = []

for car_number in range(5):
    car_data = {"color": "white", "type": "sedan"}
    cars.append(car_data)

for car in cars[:2]:
    if car_data["color"] == "white":  # Mistake here
        car_data["color"] = "black"
        car_data["type"] = "suv"
        
for car in cars:
    print(car)

# %% [markdown]
# _Revised Code_

# %%
cars = []

for car_number in range(5):
    car_data = {"color": "white", "type": "sedan"}
    cars.append(car_data)

for car in cars[:2]:
    if car["color"] == "white":  # Mistake here
        car["color"] = "black"
        car["type"] = "suv"
        
for car in cars:
    print(car)

# %% [markdown]
# ## Conclusion
# In the initial attempt, the mistake was in the condition check within the loop that modifies the first two cars. The code incorrectly referenced `car_data` instead of the current `car` in the loop. This led to the condition always evaluating to true, as it was checking the last created car's attributes rather than the attributes of the cars being iterated over.
#
# In the revised code, we correctly reference `car["color"]` to check the color of the current car in the loop. This change ensures that the intended modifications are applied to the correct cars. By understanding these concepts and the importance of referencing the correct variables, we can avoid such mistakes in future coding endeavors.
